# %% [markdown]
# Here is a simpler example of the use of LIME for image classification by using Keras (v2 or greater)

# %%
import os
import keras
from keras.applications import inception_v3 as inc_net
from keras.preprocessing import image
from keras.applications.imagenet_utils import decode_predictions
from skimage.io import imread
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
print('Notebook run using keras:', keras.__version__)
# Out:
# Using TensorFlow backend.
# Notebook run using keras: 2.0.4

# %% [markdown]
# # Using Inception
# Here we create a standard InceptionV3 pretrained model and use it on images by first preprocessing them with the preprocessing tools

# %%
inet_model = inc_net.InceptionV3()

# %%
def transform_img_fn(path_list):
    out = []
    for img_path in path_list:
        img = image.load_img(img_path, target_size=(299, 299))
        x = image.img_to_array(img)
        x = np.expand_dims(x, axis=0)
        x = inc_net.preprocess_input(x)
        out.append(x)
    return np.vstack(out)

# %% [markdown]
# ## Let's see the top 5 prediction for some image

# %%
path = '../../../Documents/me.jpg'

# %%
images = transform_img_fn([path])
# I'm dividing by 2 and adding 0.5 because of how this Inception represents images
plt.imshow(images[0] / 2 + 0.5)
preds = inet_model.predict(images)
for x in decode_predictions(preds)[0]:
    print(x)
# Out:
# ('n02963159', 'cardigan', 0.090725012)
# ('n01440764', 'tench', 0.057284221)
# ('n02514041', 'barracouta', 0.054779939)
# ('n02536864', 'coho', 0.047833733)
# ('n02092002', 'Scottish_deerhound', 0.03238124)

# %% [markdown]
# ## Explanation
# Now let's get an explanation

# %%
# %load_ext autoreload
# %autoreload 2
import os,sys
try:
    import lime
except:
    sys.path.append(os.path.join('..', '..')) # add the current directory
    import lime
from lime import lime_image

# %%
explainer = lime_image.LimeImageExplainer()

# %% [markdown]
# hide_color is the color for a superpixel turned OFF. Alternatively, if it is NONE, the superpixel will be replaced by the average of its pixels. Here, we set it to 0 (in the representation used by inception model, 0 means gray)

# %%
# %%time
# Hide color is the color for a superpixel turned OFF. Alternatively, if it is NONE, the superpixel will be replaced by the average of its pixels
explanation = explainer.explain_instance(images[0], inet_model.predict, top_labels=5, hide_color=0, num_samples=1000)
# Out:
# CPU times: user 26min 1s, sys: 2min 3s, total: 28min 5s
# Wall time: 9min 39s

# %% [markdown]
# Image classifiers are a bit slow. Notice that an explanation on my Surface Book dGPU took 1min 29s

# %% [markdown]
# ### Now let's see the explanation for the top class

# %% [markdown]
# We can see the top 5 superpixels that are most positive towards the class with the rest of the image hidden

# %%
from skimage.segmentation import mark_boundaries

# %%
explanation.top_labels
# Out:
# [474, 0, 389, 391, 177]

# %%
explanation.top_labels
# Out:
# [474, 0, 389, 391, 177]

# %%
temp, mask = explanation.get_image_and_mask(474, positive_only=True, num_features=5, hide_rest=True)
plt.imshow(mark_boundaries(temp / 2 + 0.5, mask))

# %% [markdown]
# Or with the rest of the image present:

# %%
temp, mask = explanation.get_image_and_mask(474, positive_only=True, num_features=5, hide_rest=False)
plt.imshow(mark_boundaries(temp / 2 + 0.5, mask))

# %% [markdown]
# We can also see the 'pros and cons' (pros in green, cons in red)

# %%
temp, mask = explanation.get_image_and_mask(474, positive_only=False, num_features=10, hide_rest=False)
plt.imshow(mark_boundaries(temp / 2 + 0.5, mask))

# %% [markdown]
# Or the pros and cons that have weight at least 0.1

# %%
temp, mask = explanation.get_image_and_mask(474, positive_only=False, num_features=1000, hide_rest=False, min_weight=0.1)
plt.imshow(mark_boundaries(temp / 2 + 0.5, mask))

# %% [markdown]
# ### Let's see the explanation for tench

# %% [markdown]
# Most positive towards wombat:

# %%
temp, mask = explanation.get_image_and_mask(0, positive_only=True, num_features=5, hide_rest=True)
plt.imshow(mark_boundaries(temp / 2 + 0.5, mask))

# %% [markdown]
# Pros and cons:

# %%
temp, mask = explanation.get_image_and_mask(0, positive_only=False, num_features=10, hide_rest=False)
plt.imshow(mark_boundaries(temp / 2 + 0.5, mask))
